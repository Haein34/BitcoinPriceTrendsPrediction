# %% [markdown]
# # For train, validation data

# %%
import os

import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from tqdm import tqdm

import sklearn
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score
from sklearn import metrics
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_data = pd.read_csv('F:/anaconda/JupyterNotebookDoc/Bitcoin/Bitcoin_Preprocess/traindata220819.csv')

# %%
train_data
# Out:
#       Unnamed: 0        Date  Volume_total  sentiment_index_total     High  \
# 0              0  2017-08-01          9166              -0.211215   2946.0
# 1              1  2017-08-02          8342              -0.123711   2773.8
# 2              2  2017-08-03          6933              -0.076302   2822.9
# 3              3  2017-08-04          6784              -0.094045   2892.7
# 4              4  2017-08-05          7610              -0.134034   3344.0
# ...          ...         ...           ...                    ...      ...
# 1311        1311  2021-03-27          6373              -0.029970  56531.1
# 1312        1312  2021-03-28         29995              -0.034239  56504.2
# 1313        1313  2021-03-29         30687              -0.035357  58392.6
# 1314        1314  2021-03-30         29053              -0.038034  59366.9
# 1315        1315  2021-03-31         31084              -0.068910  59795.6
#
# ...

# %%
# train_data = train_data[['Date','Volume_total','sentiment_index_total','Close','Open','High','Low','Vol',
#                         'RSI','SMA_5','SMA_20','SMA_60','EMA','MACD','signal','Stochastic RSI_fastk',
#                         'Stochastic RSI_fastd','Stochastic Oscillator Index_slowk','Stochastic Oscillator Index_slowd',
#                         'Fluctuations']]
# train_data

# %%
y_train = list(train_data['Fluctuations'])
y_train = np.array(y_train)
y_train = train_data['Fluctuations']

train_data_x = train_data[['Volume_total','sentiment_index_total','High','Low','Vol',
                        'RSI','SMA_5','SMA_20','SMA_60','EMA','MACD','signal','Stochastic RSI_fastk',
                        'Stochastic RSI_fastd','Stochastic Oscillator Index_slowk','Stochastic Oscillator Index_slowd',
                        ]]
train_data_x
# Out:
#       Volume_total  sentiment_index_total     High      Low       Vol  \
# 0             9166              -0.211215   2946.0   2659.6  123170.0
# 1             8342              -0.123711   2773.8   2668.9   81820.0
# 2             6933              -0.076302   2822.9   2717.6   68100.0
# 3             6784              -0.094045   2892.7   2779.5   68760.0
# 4             7610              -0.134034   3344.0   2875.9  159400.0
# ...            ...                    ...      ...      ...       ...
# 1311          6373              -0.029970  56531.1  54010.2   73870.0
# 1312         29995              -0.034239  56504.2  54711.3   58710.0
# 1313         30687              -0.035357  58392.6  54951.1  107910.0
# 1314         29053              -0.038034  59366.9  57077.1   86210.0
# 1315         31084              -0.068910  59795.6  56991.6   98060.0
#
#             RSI         SMA_5        SMA_20        SMA_60           EMA  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

minmaxscaler = MinMaxScaler() #min-max scaler
train_data_scale = minmaxscaler.fit_transform(train_data_x.iloc[:,:])

# %%
train_data_scale = pd.DataFrame(train_data_scale, columns=train_data_x.columns)

# %%
train_data_scale
# Out:
#       Volume_total  sentiment_index_total      High       Low       Vol  \
# 0         0.163978               0.020681  0.002918  0.000000  0.005610
# 1         0.149226               0.135777  0.000000  0.000165  0.003568
# 2         0.124000               0.198136  0.000832  0.001027  0.002891
# 3         0.121332               0.174798  0.002015  0.002124  0.002923
# 4         0.136120               0.122199  0.009661  0.003831  0.007399
# ...            ...                    ...       ...       ...       ...
# 1311      0.113974               0.259076  0.910801  0.909599  0.003176
# 1312      0.536890               0.253461  0.910345  0.922018  0.002427
# 1313      0.549279               0.251991  0.942340  0.926266  0.004857
# 1314      0.520025               0.248470  0.958848  0.963925  0.003785
# 1315      0.556387               0.207858  0.966111  0.962410  0.004370
#
#            RSI     SMA_5    SMA_20    SMA_60       EMA      MACD    signal  \
# ...

# %%
train_data_scale.to_csv('x_train_220819.csv')

# %%
y_train.to_csv('y_train_220819.csv')

# %% [markdown]
# # For test data

# %%
#검증데이터셋 처리
test_data = pd.read_csv('F:/anaconda/JupyterNotebookDoc/Bitcoin/Bitcoin_Preprocess/testdata220819.csv')

# %%
test_data
# Out:
#      Unnamed: 0        Date  Volume_total  sentiment_index_total     High  \
# 0          1316  2021-04-01         30448              -0.078429  59406.5
# 1          1317  2021-04-02         32690              -0.045090  60134.9
# 2          1318  2021-04-03         30020              -0.028048  59770.5
# 3          1319  2021-04-04         27832              -0.010563  58464.8
# 4          1320  2021-04-05         29120              -0.043819  59205.1
# ..          ...         ...           ...                    ...      ...
# 324        1640  2022-02-24         33795              -0.227519  39351.6
# 325        1641  2022-02-25         20228              -0.152857  39683.7
# 326        1642  2022-02-26         18285              -0.112934  40094.5
# 327        1643  2022-02-27         20996              -0.156030  39838.5
# 328        1644  2022-02-28         23065              -0.180143  43977.8
#
#          Low       Vol        RSI         SMA_5        SMA_20        SMA_60  \
# ...

# %%
fluctuations = list(test_data['Fluctuations'])
y_test = np.array(fluctuations)
y_test = test_data['Fluctuations']

test_data_x = test_data[['Volume_total','sentiment_index_total','High','Low','Vol',
                        'RSI','SMA_5','SMA_20','SMA_60','EMA','MACD','signal','Stochastic RSI_fastk',
                        'Stochastic RSI_fastd','Stochastic Oscillator Index_slowk','Stochastic Oscillator Index_slowd',]]
test_data_x
# Out:
#      Volume_total  sentiment_index_total     High      Low       Vol  \
# 0           30448              -0.078429  59406.5  58040.7   69040.0
# 1           32690              -0.045090  60134.9  58466.5   72370.0
# 2           30020              -0.028048  59770.5  56906.7   68740.0
# 3           27832              -0.010563  58464.8  56470.6   57210.0
# 4           29120              -0.043819  59205.1  56842.7   54130.0
# ..            ...                    ...      ...      ...       ...
# 324         33795              -0.227519  39351.6  34357.4  180470.0
# 325         20228              -0.152857  39683.7  38042.6   83780.0
# 326         18285              -0.112934  40094.5  38639.1   41550.0
# 327         20996              -0.156030  39838.5  37062.3   66140.0
# 328         23065              -0.180143  43977.8  37458.9  108070.0
#
#            RSI         SMA_5        SMA_20        SMA_60           EMA  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

#min-max scaler
test_data_scale = minmaxscaler.transform(test_data_x.iloc[:,:])

# %%
test_data_scale.shape
# Out:
# (329, 16)

# %%
test_data_scale = pd.DataFrame(test_data_scale, columns=test_data_x.columns)

# %%
test_data_scale
# Out:
#      Volume_total  sentiment_index_total      High       Low       Vol  \
# 0        0.545000               0.195338  0.959518  0.980993  0.002937
# 1        0.585140               0.239189  0.971860  0.988536  0.003102
# 2        0.537338               0.261605  0.965686  0.960906  0.002922
# 3        0.498165               0.284602  0.943563  0.953181  0.002353
# 4        0.521225               0.240861  0.956106  0.959773  0.002201
# ..            ...                    ...       ...       ...       ...
# 324      0.604923              -0.000763  0.619732  0.561479  0.008440
# 325      0.362027               0.097440  0.625358  0.626757  0.003665
# 326      0.327240               0.149952  0.632318  0.637323  0.001580
# 327      0.375777               0.093268  0.627981  0.609392  0.002794
# 328      0.412819               0.061551  0.698113  0.616418  0.004865
#
#           RSI     SMA_5    SMA_20    SMA_60       EMA      MACD    signal  \
# ...

# %%
testdata = pd.concat([test_data_scale, y_test], axis=1)

# %%
testdata.to_csv('testdata_220819.csv')
